# %%
#Specific system
import numpy as np
import matplotlib.pyplot as plt
stem = 'ResultsGS_6000'
h0mat = np.load(stem+'/h0mat.npy')
subsystem = np.load(stem+'/subsystem.npy')
gmat= np.load(stem+'/gmat.npy')
fisher = np.load(stem + '/Fisher_mat_Gamma.npy')

print(gmat[2])
print(subsystem[7])
print(fisher[2][7])
print(fisher[2][3])

# %%
#Compare groundstates
import numpy as np
import matplotlib.pyplot as plt

h0mat = np.load('ResultsGS_600/h0mat.npy')
subsystem = np.load('ResultsGS_20/subsystem.npy')

print(h0mat[3])
print(subsystem[7])

mat = [20,50,100,400,600]
fisherL4 =[]

for kk in range(0,np.size(mat)):

    fisher = np.load('ResultsGS_' + str(mat[kk]) + '/Fisher_mat.npy')
    
    fisherL4 = fisherL4 + [fisher[3,7]]

plt.plot(mat,fisherL4)
testmat = np.arange(0,6000)
plt.plot(testmat,10*testmat**(0.48))
plt.show()
# Out:
# -1.0
# 8
